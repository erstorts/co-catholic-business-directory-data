# %%
import pandas as pd
import boto3
import json
import os
import gzip

# %%
s3 = boto3.client('s3')
bucket_name = 'colorado-catholic-buisness-directory'

# %%
s3_folder = '/segment-logs/bdy6BRcrFwgvPGEtNFNwSA/'
files = []
paginator = s3.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket=bucket_name, Prefix=s3_folder.lstrip('/'))

for page in pages:
    files.extend([obj['Key'] for obj in page.get('Contents', [])])
print(files)
# Out:
# ['segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745798400000/1745862317770.events-archiver-480-20..a060ad2f-9402-46a0-a8b0-fd49782e98af.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745798400000/1745862406014.events-archiver-480-30..fa34ca49-e972-4470-8e46-368465ea3d7a.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745798400000/1745862864557.events-archiver-480-11..6b532479-d867-4f33-80c7-0c7c4126401f.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745798400000/1745863916581.events-archiver-480-13..79268d46-fc8c-4920-8326-0897d9da6c4f.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745798400000/1745863966865.events-archiver-480-5..a8a0b38a-1622-4619-a709-c7146fc32791.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745798400000/1745864254353.events-archiver-480-9..6827bc38-d8d3-4d8b-9039-cf9b54ea3a55.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745891771908.events-archiver-480-38..0d0a6ce2-92ab-4f9e-b1c2-b30f4185875d.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745891831936.events-archiver-480-17..513c1f3b-79c4-4063-a5a2-65d28ebc9b12.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745891987108.events-archiver-480-37..26f221d9-194d-437e-8fe6-cbd9ccda5b99.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745892051604.events-archiver-480-29..7567c7bf-f4b6-4c9a-b4c8-8839fbd91e8f.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898455215.events-archiver-480-1..52396b13-6bc7-4ace-8283-e15cf53ae9e9.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898679180.events-archiver-480-34..e2ee352b-b613-4c0a-b20d-deaf76dba253.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898707959.events-archiver-480-47..2a7d92ea-914b-458a-909f-b0ded032459b.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898732523.events-archiver-480-26..c0475d01-5170-46b8-bc56-8fd381a31cb0.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898740482.events-archiver-480-31..fcf47bb4-8662-4e5a-8740-b6c153938921.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898772879.events-archiver-480-5..0abe9a6f-4bb6-4ab9-9642-78390bf2cc94.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898797448.events-archiver-480-18..726165fd-8af8-43c3-b7ca-6fb5f0c496bd.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898837239.events-archiver-480-36..c2791e43-0511-447f-a369-62528024c0e4.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898861129.events-archiver-480-11..e498520e-34b7-4b73-8ee4-33629c3ae27d.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898886108.events-archiver-480-15..1349d122-6b54-4748-b2d7-7002a2c83bbf.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898907989.events-archiver-480-33..8d3079f4-22bd-4a4a-bc3a-cba42fb5f0a4.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745898924439.events-archiver-480-46..b19f23c1-2b3d-422a-aefa-1ed7ab404747.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899016007.events-archiver-480-43..7b4b18dd-9826-4d98-89d3-a6084ba16a4f.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899025327.events-archiver-480-17..1e5926f4-f7e8-4513-9bc4-f90230e54970.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899038991.events-archiver-480-22..52d9ba99-f989-41ae-b49d-f2ba279036bb.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899103073.events-archiver-480-27..863570c2-da1a-4c81-80e4-215206fd200c.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899136917.events-archiver-480-19..46e8d84d-13df-408a-b449-79f4f02478f1.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899142722.events-archiver-480-45..8d432c04-7ede-4e55-ac3a-3a8badfa20e2.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899181957.events-archiver-480-37..a930ae32-2998-4c96-8c79-b65762cbeed1.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745899220910.events-archiver-480-24..61bfa626-3bcb-4aed-b7ca-18eff2ddb43e.gz', 'segment-logs/bdy6BRcrFwgvPGEtNFNwSA/1745884800000/1745942425300.events-a ...

# %%
len(files)
# Out:
# 5568

# %%
def download_import_data(file_name):
    local_file_name = os.path.basename(file_name)
    with open(local_file_name, 'wb') as f:
        s3.download_fileobj(bucket_name, file_name, f)

    # Read the gzipped JSON file into a DataFrame
    # Segment typically stores data as newline-delimited JSON (NDJSON)
    df = pd.DataFrame()

    with gzip.open(local_file_name, 'rt') as f:
        # Read file line by line since each line is a separate JSON object
        data = [json.loads(line) for line in f]
        df = pd.DataFrame(data)

    # Expand the context column into separate columns
    context_df = pd.json_normalize(df['context'])
    # Drop the original context column and join with expanded columns
    df = df.drop('context', axis=1).join(context_df, rsuffix='_context')
    try:
        properties_df = pd.json_normalize(df['properties'])
        df = df.drop('properties', axis=1).join(properties_df, rsuffix='_properties')
    except:
        pass

    os.remove(local_file_name)

    return df

# %%
full_df = pd.DataFrame()

for file in files:
    df = download_import_data(file)
    full_df = pd.concat([full_df, df])

print(full_df.shape)
# Out:
# (9771, 59)

# %%
# Fill missing values in 'event' column with values from 'type' column
full_df['event_type'] = full_df['event'].fillna(full_df['type'])

# %%
# Convert originalTimestamp to datetime
full_df['originalTimestamp'] = pd.to_datetime(full_df['originalTimestamp'])
full_df['originalTimestamp'].head()
# Out:
# 0   2025-04-28 16:54:26.475000+00:00
# 0   2025-04-28 16:54:25.303000+00:00
# 0   2025-04-28 16:54:25.295000+00:00
# 0   2025-04-28 17:19:35.776000+00:00
# 0   2025-04-28 17:19:35.813000+00:00
# Name: originalTimestamp, dtype: datetime64[ns, UTC]

# %%
# remove columns that are not useful for analysis
full_df.drop(columns=['projectId', '_metadata', 'sentAt', 'version', '__segment_internal', 'locale', 'timezone', 'ip', 
                      'library.version', 'timestamp', 'channel', 'integrations', 'event', 'type', 'library.name', 'receivedAt'], inplace=True)
full_df.head()
# Out:
#                             anonymousId  \
# 0  e484246f-8684-4f92-ab30-1d093a3f5f60
# 0  e484246f-8684-4f92-ab30-1d093a3f5f60
# 0  e484246f-8684-4f92-ab30-1d093a3f5f60
# 0  39b9e148-9871-4dae-8fe9-b1f5845d3932
# 0  39b9e148-9871-4dae-8fe9-b1f5845d3932
#
#                                            messageId  \
# 0  ajs-next-1745859266475-8684ff92-2b30-4d09-ba3f...
# 0  ajs-next-1745859265303-246f8684-ff92-4b30-9d09...
# 0  ajs-next-1745859265295-13e48424-6f86-44ff-922b...
# 0  ajs-next-1745860775776-e2d11c37-72f4-449e-bbf8...
# 0  ajs-next-1745860775813-1c3772f4-d49e-4bf8-b69d...
#
#                              userId                originalTimestamp  \
# 0                              None 2025-04-28 16:54:26.475000+00:00
# 0                              None 2025-04-28 16:54:25.303000+00:00
# 0                              None 2025-04-28 16:54:25.295000+00:00
# 0  1743547621069x279645472884266780 2025-04-28 17:19:35.776000+00:00
# 0  1743547621069x279645472884266780 2025-04-28 17:19:35.813000+00:00
#
#                                            userAgent page.path  \
# 0  Mozilla/5.0 (Linux; Android 12; Pixel 6 Build/...         /
# 0  Mozilla/5.0 (Linux; Android 12; Pixel 6 Build/...         /
# 0  Mozilla/5.0 (Linux; Android 12; Pixel 6 Build/...         /
# 0  Mozilla/5.0 (iPhone; CPU iPhone OS 18_4_1 like...         /
# 0  Mozilla/5.0 (iPhone; CPU iPhone OS 18_4_1 like...         /
#
#                page.referrer  \
# 0  https://www.facebook.com/
# 0  https://www.facebook.com/
# 0  https://www.facebook.com/
# 0            https://bit.ly/
# 0            https://bit.ly/
#
#                                          page.search  \
# 0  ?fbclid=IwZXh0bgNhZW0CMTEAAR58oxCxVDihSoLzwMP_...
# 0  ?fbclid=IwZXh0bgNhZW0CMTEAAR58oxCxVDihSoLzwMP_...
# 0  ?fbclid=IwZXh0bgNhZW0CMTEAAR58oxCxVDihSoLzwMP_...
# 0
# 0
#
#                              page.title  \
# 0  Colorado Catholic Business Directory
# 0  Colorado Catholic Business Directory
# 0  Colorado Catholic Business Directory
# 0  Colorado Catholic Business Directory
# 0  Colorado Catholic Business Directory
#
#                                             page.url  ... address  \
# 0  https://coloradocatholicbusinessdirectory.com/...  ...     NaN
# 0  https://coloradocatholicbusinessdirectory.com/...  ...     NaN
# 0  https://coloradocatholicbusinessdirectory.com/...  ...     NaN
# 0     https://coloradocatholicbusinessdirectory.com/  ...     NaN
# 0     https://coloradocatholicbusinessdirectory.com/  ...     NaN
#
#   other_category description display_email business_name main_category phone  \
# 0            NaN         NaN           NaN           NaN           NaN   NaN
# 0            NaN         NaN           NaN           NaN           NaN   NaN
# 0            NaN         NaN           NaN           NaN           NaN   NaN
# 0            NaN         NaN           NaN           NaN           NaN   NaN
# 0            NaN         NaN           NaN           NaN           NaN   NaN
#
#   sub_category website  event_type
# 0          NaN     NaN  impression
# 0          NaN     NaN  impression
# 0          NaN     NaN        page
# 0          NaN     NaN  impression
# 0          NaN     NaN  impression
#
# [5 rows x 44 columns]

# %%
full_df.columns
# Out:
# Index(['anonymousId', 'messageId', 'userId', 'originalTimestamp', 'userAgent',
#        'page.path', 'page.referrer', 'page.search', 'page.title', 'page.url',
#        'userAgentData.brands', 'userAgentData.mobile',
#        'userAgentData.platform', 'business_id', 'sponsored_listing',
#        'category', 'name', 'path', 'referrer', 'search', 'title', 'url',
#        'category_properties', 'name_properties', 'button_name', 'location',
#        'city', 'search_text', 'parish', 'traits', 'input_num', 'input_name',
#        'email', 'input_value', 'address', 'other_category', 'description',
#        'display_email', 'business_name', 'main_category', 'phone',
#        'sub_category', 'website', 'event_type'],
#       dtype='object')

# %%
full_df.reset_index(drop=True, inplace=True)
print(full_df.shape)
full_df.to_csv('ccbd-data.csv', index=False)
# Out:
# (9771, 44)
